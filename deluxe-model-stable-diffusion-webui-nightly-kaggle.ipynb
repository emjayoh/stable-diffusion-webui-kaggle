# %% [markdown]
# # **Stable Diffusion Webui Nightly**
#
# # Note:
#
# > * This notebook might not work properly after some time because Nightly version notebooks are updated on regular basis.
#
# > * In this Nightly Version notebook the default height of inpaint is 720p which is for desktop so if you are working on Android you have to manually set the inpaint height in "User Interface" which is present in Setting tab, Around 300-400 pix should be fine.
#
#
# # Current Models:
# > * DivineEleganceMix_V5 & VAE
#
# # Although you can change It any time 👻
#
#
# # **NSFW (⁠｡⁠•̀⁠ᴗ⁠-⁠)⁠✧**
# ***Just make sure you are running it privately Otherwise say goodbye to your Account*** 🥲
#
# ***Special thanks to [Camenduru](https://github.com/camenduru)***

# %%
# !python -m pip install -U pip
# !pip install --upgrade setuptools==67.7.2
# !pip install ez_setup

import os
os.mkdir('/kaggle/temp')
# %cd /kaggle/temp
# %env TF_CPP_MIN_LOG_LEVEL=/temp
# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt-get install -qq libunwind8-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb 

# !apt -y install -qq aria2 libcairo2-dev pkg-config python3-dev
# !pip install -q torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U
# !pip install -q xformers==0.0.19 triton==2.0.0 -U
# !pip install --upgrade tensorflow-io

# Extensions 
# Don't try to run all the extension otherwise the machine would run out of memory and terminate the session.
# !git clone -b v2.3 https://github.com/camenduru/stable-diffusion-webui
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-nsfw-censor /kaggle/temp/stable-diffusion-webui/extensions/stable-diffusion-webui-nsfw-censor 
# <⁠(⁠￣⁠︶⁠￣⁠)⁠↗ Kaggle safety features to prevent abuse and TOS infringemenet. Replace NSFW images with blank
# !git clone https://huggingface.co/ogstradamus/lora-jamz_rmada2.1-70 /kaggle/temp/stable-diffusion-webui/models/Lora/jamz-2.1
# !git clone https://huggingface.co/ogstradamus/lora-jamz_anylora /kaggle/temp/stable-diffusion-webui/models/Lora/jamz-1.5
# !git clone https://huggingface.co/ogstradamus/loras /kaggle/temp/stable-diffusion-webui/models/Lora/etc
# !git clone https://huggingface.co/nolanaatama/embeddings /kaggle/temp/stable-diffusion-webui/embeddings/neutral
# !git clone https://huggingface.co/embed/negative /kaggle/temp/stable-diffusion-webui/embeddings/negative
# !git clone https://huggingface.co/embed/lora /kaggle/temp/stable-diffusion-webui/models/Lora/positive
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth -d /kaggle/temp/stable-diffusion-webui/models/ESRGAN -o 4x-UltraSharp.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/datasets/joachimsallstrom/lux_np/resolve/main/lux_np.pt /kaggle/temp/stable-diffusion-webui/embeddings/negative -o lux_np.pt
# !wget https://raw.githubusercontent.com/camenduru/stable-diffusion-webui-scripts/main/run_n_times.py -O /kaggle/temp/stable-diffusion-webui/scripts/run_n_times.py
# !git clone https://github.com/KohakuBlueleaf/a1111-sd-webui-lycoris /kaggle/temp/stable-diffusion-webui/extensions/a1111-sd-webui-lycoris
# !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete.git /kaggle/temp/stable-diffusion-webui/extensions/tag-autocomplete
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui /kaggle/temp/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui
# !git clone https://github.com/camenduru/stable-diffusion-webui-images-browser /kaggle/temp/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser
# !git clone https://github.com/camenduru/stable-diffusion-webui-huggingface /kaggle/temp/stable-diffusion-webui/extensions/stable-diffusion-webui-huggingface
# !git clone https://github.com/camenduru/sd-civitai-browser /kaggle/temp/stable-diffusion-webui/extensions/sd-civitai-browser
# !git clone https://github.com/kohya-ss/sd-webui-additional-networks /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-additional-networks
# !git clone https://github.com/Mikubill/sd-webui-controlnet /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet
# !git clone https://github.com/fkunn1326/openpose-editor /kaggle/temp/stable-diffusion-webui/extensions/openpose-editor
# !git clone https://github.com/jexom/sd-webui-depth-lib /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-depth-lib
# !git clone https://github.com/hnmr293/posex /kaggle/temp/stable-diffusion-webui/extensions/posex
# !git clone https://github.com/nonnonstop/sd-webui-3d-open-pose-editor /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-3d-open-pose-editor
# !git clone https://github.com/camenduru/sd-webui-tunnels /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-tunnels
# !git clone https://github.com/etherealxx/batchlinks-webui /kaggle/temp/stable-diffusion-webui/extensions/batchlinks-webui
# !git clone https://github.com/camenduru/stable-diffusion-webui-catppuccin /kaggle/temp/stable-diffusion-webui/extensions/stable-diffusion-webui-catppuccin
# !git clone https://github.com/camenduru/a1111-sd-webui-locon /kaggle/temp/stable-diffusion-webui/extensions/a1111-sd-webui-locon
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-rembg /kaggle/temp/stable-diffusion-webui/extensions/stable-diffusion-webui-rembg
# !git clone https://github.com/ashen-sensored/stable-diffusion-webui-two-shot /kaggle/temp/stable-diffusion-webui/extensions/stable-diffusion-webui-two-shot
# !git clone https://github.com/thomasasfk/sd-webui-aspect-ratio-helper /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-aspect-ratio-helper
# !git clone https://github.com/tjm35/asymmetric-tiling-sd-webui /kaggle/temp/stable-diffusion-webui/extensions/asymmetric-tiling-sd-webui
# %cd /kaggle/temp/stable-diffusion-webui
# !git reset --hard
# !git -C /kaggle/temp/stable-diffusion-webui/repositories/stable-diffusion-stability-ai reset --hard

# Controlnet
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11e_sd15_ip2p_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11e_sd15_shuffle_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_canny_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11f1p_sd15_depth_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_inpaint_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_lineart_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_mlsd_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_normalbae_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_openpose_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_scribble_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_seg_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_softedge_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15s2_lineart_anime_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile_fp16.safetensors -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11f1e_sd15_tile_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_ip2p_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11e_sd15_ip2p_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_shuffle_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11e_sd15_shuffle_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_canny_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_canny_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1p_sd15_depth_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11f1p_sd15_depth_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_inpaint_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_inpaint_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_lineart_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_lineart_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_mlsd_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_mlsd_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_normalbae_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_normalbae_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_openpose_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_openpose_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_scribble_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_scribble_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_seg_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_seg_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_softedge_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_softedge_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15s2_lineart_anime_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15s2_lineart_anime_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1e_sd15_tile_fp16.yaml -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11f1e_sd15_tile_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_style_sd14v1.pth -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_style_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd14v1.pth -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_sketch_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_seg_sd14v1.pth -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_seg_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_openpose_sd14v1.pth -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_openpose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_keypose_sd14v1.pth -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_keypose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd14v1.pth -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_depth_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_color_sd14v1.pth -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_color_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd14v1.pth -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_canny_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd15v2.pth -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_canny_sd15v2.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd15v2.pth -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_depth_sd15v2.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd15v2.pth -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_sketch_sd15v2.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_zoedepth_sd15v1.pth -d /kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_zoedepth_sd15v1.pth    

#########################
# Models    
########################

# VAE
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o sd-vae-84000.vae.pt   
    
# FKINC-SCIFI + YAML
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/66578 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o fkingscifi.safetensors
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/66578?type=Config -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o fkingscifi.yaml
    
# ETHEREAL MIX    
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/104819 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o etherealmix.safetensors

# DREAD
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/104018 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o dread.safetensors

# VINTEPROTOGEN
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/23690 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o vinteprotogen.safetensors

# LYRIEL
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/72396 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o lyriel.safetensors

# RMADA MERGE + YAML
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/46259 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o rmada.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/46259?type=Config -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o rmada.yaml

# ILLUMINUTTY + YAML    
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/42304 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o illuminutty.safetensors
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/42304?type=Config -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o illuminutty.yaml

# REALISM-ENGINE + YAML    
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/20414 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o realism-engine.safetensors
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/20414?type=Config -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o realism-engine.yaml

# CLASSIC NEGATIVE + YAML    
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7388 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o classic-negative.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7388?type=Config -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o classic-negative.yaml

# GRAPHIC-DESIGN + YAML
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/19546 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o graphic-design.safetensors
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/19546?type=Config -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o graphic-design.yaml
    
# ARTIUS + YAML
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/33216 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o artius.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/33216?type=Config -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o artius.yaml
    
# PRMJ + YAML    
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7592 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o prmj.safetensors
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7592?type=Config -d //kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o prmj.yaml

# PROLUX
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/84957 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o prolux.safetensors

# AETHER-LUX    
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/81037 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o aether-lux.safetensors
    
# JUGGERNAUT + YAML
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/109134 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o juggernaut-vae.safetensors
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/109134?type=Config -d /content/stable-diffusion-webui/models/Stable-diffusion -o juggernaut-vae.yaml

# INPAINTING + YAML
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/108133 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o juggernaut-inpaint.safetensors
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/108133?type=Config -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o juggernaut-inpaint.yaml

# TSHIRT 1
# https://civitai.com/models/5256
# #PRINTDESIGN
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6098 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o tshirt1.safetensors

# TSHIRT 2
# https://civitai.com/models/4694Ç
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7554 -d /kaggle/temp/stable-diffusion-webui/models/Stable-diffusion -o tshirt2.safetensors


# !sed -i -e '''/from modules import launch_utils/a\import os''' /kaggle/temp/stable-diffusion-webui/launch.py
# !sed -i -e '''/        prepare_environment()/a\        os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /kaggle/temp/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /kaggle/temp/stable-diffusion-webui/launch.py
# !sed -i -e 's/\["sd_model_checkpoint"\]/\["sd_model_checkpoint","sd_vae","CLIP_stop_at_last_layers"\]/g' /kaggle/temp/stable-diffusion-webui/modules/shared.py
# !python launch.py --share --xformers --enable-insecure-extension-access --theme dark --gradio-queue
# Out:
# Requirement already satisfied: pip in /opt/conda/lib/python3.10/site-packages (23.1.2)
# Collecting pip
#   Downloading pip-23.2-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 32.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.2
#     Uninstalling pip-23.1.2:
#       Successfully uninstalled pip-23.1.2
# Successfully installed pip-23.2
# Collecting setuptools==67.7.2
#   Downloading setuptools-67.7.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 59.8.0
#     Uninstalling setuptools-59.8.0:
#       Successfully uninstalled setuptools-59.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-api 1.18.0 requires importlib-metadata~=6.0.0, but you have importlib-metadata 6.7.0 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.23.5 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.1 which is incompatible.
# Successfully installed setuptools-67.7.2
# Collecting ez_setup
#   Downloading ez_setup-0.9.tar.gz (6.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ez_setup
#   Building wheel for ez_setup (setup.py) ... done
#   Created wheel for ez_setup: filename=ez_setup-0.9-py3-none-any.whl size=10997 sha256=3723b193dc3cbd80e42ba751aa1baee1a5811a2058441eeff48d98ce70f1681e
#   Stored in directory: /root/.cache/pip/wheels/7a/d6/77/8f495e85fb7df23d41c328b9ea3cf0d9e83631b20bba479293
# Successfully built ez_setup
# Installing collected packages: ez_setup
# Successfully installed ez_setup-0.9
# /kaggle/temp
# env: TF_CPP_MIN_LOG_LEVEL=/temp
# 15 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: http://packages.cloud.google.com/apt/dists/gcsfuse-focal/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# W: https://packages.cloud.google.com/apt/dists/google-fast-socket/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# --2023-07-17 08:19:42--  http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 185.125.189.228, 185.125.189.229, 2620:2d:4000:1001::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|185.125.189.228|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 203696 (199K) [application/x-debian-package]
# Saving to: ‘libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb’
#
# libgoogle-perftools 100%[===================>] 198.92K   394KB/s    in 0.5s
#
# 2023-07-17 08:19:43 (394 KB/s) - ‘libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb’ saved [203696/203696]
#
# --2023-07-17 08:19:44--  https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# Resolving launchpad.net (launchpad.net)... 185.125.189.223, 185.125.189.222, 2620:2d:4000:1001::8003, ...
# Connecting to launchpad.net (launchpad.net)|185.125.189.223|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://launchpadlibrarian.net/367274642/google-perftools_2.5-2.2ubuntu3_all.deb [following]
# --2023-07-17 08:19:45--  https://launchpadlibrarian.net/367274642/google-perftools_2.5-2.2ubuntu3_all.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 185.125.189.228, 185.125.189.229, 2620:2d:4000:1001::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|185.125.189.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 294224 (287K) [application/x-debian-package]
# Saving to: ‘google-perftools_2.5-2.2ubuntu3_all.deb’
#
# google-perftools_2. 100%[===================>] 287.33K   518KB/s    in 0.6s
#
# 2023-07-17 08:19:46 (518 KB/s) - ‘google-perftools_2.5-2.2ubuntu3_all.deb’ saved [294224/294224]
#
# --2023-07-17 08:19:47--  https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpad.net (launchpad.net)... 185.125.189.223, 185.125.189.222, 2620:2d:4000:1001::8004, ...
# Connecting to launchpad.net (launchpad.net)|185.125.189.223|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://launchpadlibrarian.net/367274648/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb [following]
# --2023-07-17 08:19:48--  https://launchpadlibrarian.net/367274648/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 185.125.189.229, 185.125.189.228, 2620:2d:4000:1001::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|185.125.189.229|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 91644 (89K) [application/x-debian-package]
# Saving to: ‘libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb’
#
# libtcmalloc-minimal 100%[===================>]  89.50K   304KB/s    in 0.3s
#
# 2023-07-17 08:19:49 (304 KB/s) - ‘libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb’ saved [91644/91644]
#
# --2023-07-17 08:19:50--  https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpad.net (launchpad.net)... 185.125.189.223, 185.125.189.222, 2620:2d:4000:1001::8003, ...
# Connecting to launchpad.net (launchpad.net)|185.125.189.223|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://launchpadlibrarian.net/367274647/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb [following]
# --2023-07-17 08:19:50--  https://launchpadlibrarian.net/367274647/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 185.125.189.228, 185.125.189.229, 2620:2d:4000:1001::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|185.125.189.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 189628 (185K) [application/x-debian-package]
# Saving to: ‘libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb’
#
# libgoogle-perftools 100%[===================>] 185.18K   377KB/s    in 0.5s
#
# 2023-07-17 08:19:51 (377 KB/s) - ‘libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb’ saved [189628/189628]
#
# Selecting previously unselected package liblzma-dev:amd64.
# (Reading database ... 113701 files and directories currently installed.)
# Preparing to unpack .../liblzma-dev_5.2.5-2ubuntu1_amd64.deb ...
# Unpacking liblzma-dev:amd64 (5.2.5-2ubuntu1) ...
# Selecting previously unselected package libunwind-dev:amd64.
# Preparing to unpack .../libunwind-dev_1.3.2-2build2_amd64.deb ...
# Unpacking libunwind-dev:amd64 (1.3.2-2build2) ...
# Setting up liblzma-dev:amd64 (5.2.5-2ubuntu1) ...
# Setting up libunwind-dev:amd64 (1.3.2-2build2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Selecting previously unselected package google-perftools.
# (Reading database ... 113794 files and directories currently installed.)
# Preparing to unpack google-perftools_2.5-2.2ubuntu3_all.deb ...
# Unpacking google-perftools (2.5-2.2ubuntu3) ...
# Selecting previously unselected package libgoogle-perftools-dev.
# Preparing to unpack libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libgoogle-perftools-dev (2.5-2.2ubuntu3) ...
# Selecting previously unselected package libgoogle-perftools4.
# Preparing to unpack libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libgoogle-perftools4 (2.5-2.2ubuntu3) ...
# Selecting previously unselected package libtcmalloc-minimal4.
# Preparing to unpack libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libtcmalloc-minimal4 (2.5-2.2ubuntu3) ...
# Setting up libtcmalloc-minimal4 (2.5-2.2ubuntu3) ...
# Setting up libgoogle-perftools4 (2.5-2.2ubuntu3) ...
# Setting up google-perftools (2.5-2.2ubuntu3) ...
# Setting up libgoogle-perftools-dev (2.5-2.2ubuntu3) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# env: LD_PRELOAD=libtcmalloc.so
# pkg-config is already the newest version (0.29.2-1ubuntu3).
# The following additional packages will be installed:
#   javascript-common libaria2-0 libblkid-dev libc-ares2
#   libcairo-script-interpreter2 libexpat1-dev libffi-dev libfontconfig-dev
#   libfontconfig1-dev libglib2.0-dev libglib2.0-dev-bin libice-dev libjs-jquery
#   libjs-sphinxdoc libjs-underscore liblzo2-2 libmount-dev libpcre16-3
#   libpcre2-16-0 libpcre2-32-0 libpcre2-dev libpcre2-posix3 libpcre3-dev
#   libpcre32-3 libpcrecpp0v5 libpixman-1-dev libpthread-stubs0-dev
#   libpython3-dev libpython3.10-dev libselinux1-dev libsepol-dev libsm-dev
#   libssh2-1 libx11-dev libxau-dev libxcb-render0-dev libxcb-shm0-dev
#   libxcb1-dev libxdmcp-dev libxext-dev libxrender-dev python3.10-dev uuid-dev
#   x11proto-dev xorg-sgml-doctools xtrans-dev
# Suggested packages:
#   apache2 | lighttpd | httpd libcairo2-doc libgirepository1.0-dev
#   libglib2.0-doc libgdk-pixbuf2.0-bin | libgdk-pixbuf2.0-dev libxml2-utils
#   libice-doc libsm-doc libx11-doc libxcb-doc libxext-doc
# The following NEW packages will be installed:
#   aria2 javascript-common libaria2-0 libblkid-dev libc-ares2
#   libcairo-script-interpreter2 libcairo2-dev libexpat1-dev libffi-dev
#   libfontconfig-dev libfontconfig1-dev libglib2.0-dev libglib2.0-dev-bin
#   libice-dev libjs-jquery libjs-sphinxdoc libjs-underscore liblzo2-2
#   libmount-dev libpcre16-3 libpcre2-16-0 libpcre2-32-0 libpcre2-dev
#   libpcre2-posix3 libpcre3-dev libpcre32-3 libpcrecpp0v5 libpixman-1-dev
#   libpthread-stubs0-dev libpython3-dev libpython3.10-dev libselinux1-dev
#   libsepol-dev libsm-dev libssh2-1 libx11-dev libxau-dev libxcb-render0-dev
#   libxcb-shm0-dev libxcb1-dev libxdmcp-dev libxext-dev libxrender-dev
#   python3-dev python3.10-dev uuid-dev x11proto-dev xorg-sgml-doctools
#   xtrans-dev
# 0 upgraded, 49 newly installed, 0 to remove and 19 not upgraded.
# Need to get 15.4 MB of archives.
# After this operation, 63.4 MB of additional disk space will be used.
# Extracting templates from packages: 100%
#
# 78Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 113909 files and directories currently installed.)
# Preparing to unpack .../00-libc-ares2_1.18.1-1ubuntu0.22.04.2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libssh2-1:amd64.
# Preparing to unpack .../01-libssh2-1_1.10.0-3_amd64.deb ...
# Unpacking libssh2-1:amd64 (1.10.0-3) ...
# 7Progress: [  2%] [#.........................................................] 8Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../02-libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package aria2.
# Preparing to unpack .../03-aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# 7Progress: [  4%] [##........................................................] 8Selecting previously unselected package javascript-common.
# Preparing to unpack .../04-javascript-common_11+nmu1_all.deb ...
# Unpacking javascript-common (11+nmu1) ...
# 7Progress: [  5%] [##........................................................] 8Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../05-liblzo2-2_2.10-2build3_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2build3) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../06-libcairo-script-interpreter2_1.16.0-5ubuntu2_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.16.0-5ubuntu2) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package libexpat1-dev:amd64.
# Preparing to unpack .../07-libexpat1-dev_2.4.7-1ubuntu0.2_amd64.deb ...
# Unpacking libexpat1-dev:amd64 (2.4.7-1ubuntu0.2) ...
# 7Progress: [  8%] [####......................................................] 8Selecting previously unselected package uuid-dev:amd64.
# Preparing to unpack .../08-uuid-dev_2.37.2-4ubuntu3_amd64.deb ...
# Unpacking uuid-dev:amd64 (2.37.2-4ubuntu3) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libfontconfig-dev:amd64.
# Preparing to unpack .../09-libfontconfig-dev_2.13.1-4.2ubuntu5_amd64.deb ...
# Unpacking libfontconfig-dev:amd64 (2.13.1-4.2ubuntu5) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package libfontconfig1-dev:amd64.
# Preparing to unpack .../10-libfontconfig1-dev_2.13.1-4.2ubuntu5_amd64.deb ...
# Unpacking libfontconfig1-dev:amd64 (2.13.1-4.2ubuntu5) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package xorg-sgml-doctools.
# Preparing to unpack .../11-xorg-sgml-doctools_1%3a1.11-1.1_all.deb ...
# Unpacking xorg-sgml-doctools (1:1.11-1.1) ...
# 7Progress: [ 12%] [#######...................................................] 8Selecting previously unselected package x11proto-dev.
# Preparing to unpack .../12-x11proto-dev_2021.5-1_all.deb ...
# Unpacking x11proto-dev (2021.5-1) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package libxau-dev:amd64.
# Preparing to unpack .../13-libxau-dev_1%3a1.0.9-1build5_amd64.deb ...
# Unpacking libxau-dev:amd64 (1:1.0.9-1build5) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libxdmcp-dev:amd64.
# Preparing to unpack .../14-libxdmcp-dev_1%3a1.1.3-0ubuntu5_amd64.deb ...
# Unpacking libxdmcp-dev:amd64 (1:1.1.3-0ubuntu5) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package xtrans-dev.
# Preparing to unpack .../15-xtrans-dev_1.4.0-1_all.deb ...
# Unpacking xtrans-dev (1.4.0-1) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libpthread-stubs0-dev:amd64.
# Preparing to unpack .../16-libpthread-stubs0-dev_0.4-1build2_amd64.deb ...
# Unpacking libpthread-stubs0-dev:amd64 (0.4-1build2) ...
# 7Progress: [ 17%] [##########................................................] 8Selecting previously unselected package libxcb1-dev:amd64.
# Preparing to unpack .../17-libxcb1-dev_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb1-dev:amd64 (1.14-3ubuntu3) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package libx11-dev:amd64.
# Preparing to unpack .../18-libx11-dev_2%3a1.7.5-1ubuntu0.2_amd64.deb ...
# Unpacking libx11-dev:amd64 (2:1.7.5-1ubuntu0.2) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libxrender-dev:amd64.
# Preparing to unpack .../19-libxrender-dev_1%3a0.9.10-1build4_amd64.deb ...
# Unpacking libxrender-dev:amd64 (1:0.9.10-1build4) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package libxext-dev:amd64.
# Preparing to unpack .../20-libxext-dev_2%3a1.3.4-1build1_amd64.deb ...
# Unpacking libxext-dev:amd64 (2:1.3.4-1build1) ...
# 7Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../21-libice-dev_2%3a1.0.10-1build2_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-1build2) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../22-libsm-dev_2%3a1.2.3-1build2_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1build2) ...
# 7Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../23-libpixman-1-dev_0.40.0-1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# 7Progress: [ 24%] [##############............................................] 8Selecting previously unselected package libxcb-render0-dev:amd64.
# Preparing to unpack .../24-libxcb-render0-dev_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-render0-dev:amd64 (1.14-3ubuntu3) ...
# 7Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../25-libxcb-shm0-dev_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.14-3ubuntu3) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../26-libffi-dev_3.4.2-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.4.2-4) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libglib2.0-dev-bin.
# Preparing to unpack .../27-libglib2.0-dev-bin_2.72.4-0ubuntu2.2_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.72.4-0ubuntu2.2) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libblkid-dev:amd64.
# Preparing to unpack .../28-libblkid-dev_2.37.2-4ubuntu3_amd64.deb ...
# Unpacking libblkid-dev:amd64 (2.37.2-4ubuntu3) ...
# 7Progress: [ 29%] [#################.........................................] 8Selecting previously unselected package libsepol-dev:amd64.
# Preparing to unpack .../29-libsepol-dev_3.3-1build1_amd64.deb ...
# Unpacking libsepol-dev:amd64 (3.3-1build1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libpcre2-16-0:amd64.
# Preparing to unpack .../30-libpcre2-16-0_10.39-3ubuntu0.1_amd64.deb ...
# Unpacking libpcre2-16-0:amd64 (10.39-3ubuntu0.1) ...
# 7Progress: [ 31%] [##################........................................] 8Selecting previously unselected package libpcre2-32-0:amd64.
# Preparing to unpack .../31-libpcre2-32-0_10.39-3ubuntu0.1_amd64.deb ...
# Unpacking libpcre2-32-0:amd64 (10.39-3ubuntu0.1) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libpcre2-posix3:amd64.
# Preparing to unpack .../32-libpcre2-posix3_10.39-3ubuntu0.1_amd64.deb ...
# Unpacking libpcre2-posix3:amd64 (10.39-3ubuntu0.1) ...
# 7Progress: [ 34%] [###################.......................................] 8Selecting previously unselected package libpcre2-dev:amd64.
# Preparing to unpack .../33-libpcre2-dev_10.39-3ubuntu0.1_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libpcre2-dev:amd64 (10.39-3ubuntu0.1) ...
# Selecting previously unselected package libselinux1-dev:amd64.
# Preparing to unpack .../34-libselinux1-dev_3.3-1build2_amd64.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libselinux1-dev:amd64 (3.3-1build2) ...
# Selecting previously unselected package libmount-dev:amd64.
# Preparing to unpack .../35-libmount-dev_2.37.2-4ubuntu3_amd64.deb ...
# 7Progress: [ 36%] [####################......................................] 8Unpacking libmount-dev:amd64 (2.37.2-4ubuntu3) ...
# Selecting previously unselected package libpcre16-3:amd64.
# Preparing to unpack .../36-libpcre16-3_2%3a8.39-13ubuntu0.22.04.1_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libpcre16-3:amd64 (2:8.39-13ubuntu0.22.04.1) ...
# Selecting previously unselected package libpcre32-3:amd64.
# Preparing to unpack .../37-libpcre32-3_2%3a8.39-13ubuntu0.22.04.1_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking libpcre32-3:amd64 (2:8.39-13ubuntu0.22.04.1) ...
# Selecting previously unselected package libpcrecpp0v5:amd64.
# Preparing to unpack .../38-libpcrecpp0v5_2%3a8.39-13ubuntu0.22.04.1_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libpcrecpp0v5:amd64 (2:8.39-13ubuntu0.22.04.1) ...
# Selecting previously unselected package libpcre3-dev:amd64.
# Preparing to unpack .../39-libpcre3-dev_2%3a8.39-13ubuntu0.22.04.1_amd64.deb ...
# 7Progress: [ 40%] [#######################...................................] 8Unpacking libpcre3-dev:amd64 (2:8.39-13ubuntu0.22.04.1) ...
# Selecting previously unselected package libglib2.0-dev:amd64.
# Preparing to unpack .../40-libglib2.0-dev_2.72.4-0ubuntu2.2_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking libglib2.0-dev:amd64 (2.72.4-0ubuntu2.2) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../41-libcairo2-dev_1.16.0-5ubuntu2_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.16.0-5ubuntu2) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../42-libjs-jquery_3.6.0+dfsg+~3.5.13-1_all.deb ...
# Unpacking libjs-jquery (3.6.0+dfsg+~3.5.13-1) ...
# 7Progress: [ 43%] [#########################.................................] 8Selecting previously unselected package libjs-underscore.
# Preparing to unpack .../43-libjs-underscore_1.13.2~dfsg-2_all.deb ...
# Unpacking libjs-underscore (1.13.2~dfsg-2) ...
# 7Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libjs-sphinxdoc.
# Preparing to unpack .../44-libjs-sphinxdoc_4.3.2-1_all.deb ...
# Unpacking libjs-sphinxdoc (4.3.2-1) ...
# 7Progress: [ 45%] [##########################................................] 8Selecting previously unselected package libpython3.10-dev:amd64.
# Preparing to unpack .../45-libpython3.10-dev_3.10.6-1~22.04.2ubuntu1.1_amd64.deb ...
# Unpacking libpython3.10-dev:amd64 (3.10.6-1~22.04.2ubuntu1.1) ...
# 7Progress: [ 46%] [##########################................................] 8Selecting previously unselected package libpython3-dev:amd64.
# Preparing to unpack .../46-libpython3-dev_3.10.6-1~22.04_amd64.deb ...
# Unpacking libpython3-dev:amd64 (3.10.6-1~22.04) ...
# 7Progress: [ 47%] [###########################...............................] 8Selecting previously unselected package python3.10-dev.
# Preparing to unpack .../47-python3.10-dev_3.10.6-1~22.04.2ubuntu1.1_amd64.deb ...
# Unpacking python3.10-dev (3.10.6-1~22.04.2ubuntu1.1) ...
# 7Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package python3-dev.
# Preparing to unpack .../48-python3-dev_3.10.6-1~22.04_amd64.deb ...
# Unpacking python3-dev (3.10.6-1~22.04) ...
# 7Progress: [ 49%] [############################..............................] 8Setting up libpcrecpp0v5:amd64 (2:8.39-13ubuntu0.22.04.1) ...
# 7Progress: [ 50%] [#############################.............................] 8Setting up javascript-common (11+nmu1) ...
# 7Progress: [ 51%] [#############################.............................] 8Setting up libglib2.0-dev-bin (2.72.4-0ubuntu2.2) ...
# 7Progress: [ 52%] [##############################............................] 8Setting up libpixman-1-dev:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up libpcre16-3:amd64 (2:8.39-13ubuntu0.22.04.1) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up liblzo2-2:amd64 (2.10-2build3) ...
# 7Progress: [ 55%] [################################..........................] 8Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libffi-dev:amd64 (3.4.2-4) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up libpthread-stubs0-dev:amd64 (0.4-1build2) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libpcre2-16-0:amd64 (10.39-3ubuntu0.1) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up xtrans-dev (1.4.0-1) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libpcre2-32-0:amd64 (10.39-3ubuntu0.1) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libexpat1-dev:amd64 (2.4.7-1ubuntu0.2) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up uuid-dev:amd64 (2.37.2-4ubuntu3) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libpcre32-3:amd64 (2:8.39-13ubuntu0.22.04.1) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libpython3.10-dev:amd64 (3.10.6-1~22.04.2ubuntu1.1) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libsepol-dev:amd64 (3.3-1build1) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libpcre2-posix3:amd64 (10.39-3ubuntu0.1) ...
# 7Progress: [ 67%] [#######################################...................] 8Setting up python3.10-dev (3.10.6-1~22.04.2ubuntu1.1) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libssh2-1:amd64 (1.10.0-3) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up xorg-sgml-doctools (1:1.11-1.1) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libjs-jquery (3.6.0+dfsg+~3.5.13-1) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libjs-underscore (1.13.2~dfsg-2) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up x11proto-dev (2021.5-1) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libcairo-script-interpreter2:amd64 (1.16.0-5ubuntu2) ...
# 7Progress: [ 74%] [###########################################...............] 8Setting up libblkid-dev:amd64 (2.37.2-4ubuntu3) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libaria2-0:amd64 (1.36.0-1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libpython3-dev:amd64 (3.10.6-1~22.04) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libxau-dev:amd64 (1:1.0.9-1build5) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libpcre2-dev:amd64 (10.39-3ubuntu0.1) ...
# 7Progress: [ 79%] [##############################################............] 8Setting up libice-dev:amd64 (2:1.0.10-1build2) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libfontconfig-dev:amd64 (2.13.1-4.2ubuntu5) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libsm-dev:amd64 (2:1.2.3-1build2) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libselinux1-dev:amd64 (3.3-1build2) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up aria2 (1.36.0-1) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libpcre3-dev:amd64 (2:8.39-13ubuntu0.22.04.1) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up libxdmcp-dev:amd64 (1:1.1.3-0ubuntu5) ...
# 7Progress: [ 86%] [##################################################........] 8Setting up libjs-sphinxdoc (4.3.2-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libmount-dev:amd64 (2.37.2-4ubuntu3) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libfontconfig1-dev:amd64 (2.13.1-4.2ubuntu5) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libxcb1-dev:amd64 (1.14-3ubuntu3) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libx11-dev:amd64 (2:1.7.5-1ubuntu0.2) ...
# 7Progress: [ 91%] [#####################################################.....] 8Setting up libxcb-shm0-dev:amd64 (1.14-3ubuntu3) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libglib2.0-dev:amd64 (2.72.4-0ubuntu2.2) ...
# Setting up python3-dev (3.10.6-1~22.04) ...
# 7Progress: [ 93%] [######################################################....] 8Setting up libxcb-render0-dev:amd64 (1.14-3ubuntu3) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libxext-dev:amd64 (2:1.3.4-1build1) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libxrender-dev:amd64 (1:0.9.10-1build4) ...
# 7Progress: [ 96%] [#######################################################...] 8Processing triggers for install-info (6.8-4build1) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.2) ...
# 7Progress: [ 97%] [########################################################..] 87Progress: [ 98%] [#########################################################.] 8Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Setting up libcairo2-dev:amd64 (1.16.0-5ubuntu2) ...
# 7Progress: [ 99%] [#########################################################.] 8
# 78tcmalloc: large alloc 2267275264 bytes == 0x5bcdcdd76000 @  0x79a66cc331e7 0x5bcdcc289d45 0x5bcdcc2b96f6 0x5bcdcc2d39e9 0x5bcdcc39c558 0x5bcdcc32e075 0x5bcdcc32de6b 0x5bcdcc2bd4ad 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a38fa 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2be648 0x5bcdcc344572 0x5bcdcc378ac8 0x5bcdcc2a7142
# tcmalloc: large alloc 2834096128 bytes == 0x5bce54fb4000 @  0x79a66cc34615 0x5bcdcc2d39e9 0x5bcdcc39c558 0x5bcdcc32e075 0x5bcdcc32de6b 0x5bcdcc2bd4ad 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a38fa 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2be648 0x5bcdcc344572 0x5bcdcc378ac8 0x5bcdcc2a7142 0x5bcdcc2be4f2 0x5bcdcc2a7142
# tcmalloc: large alloc 2267275264 bytes == 0x5bcdcdd76000 @  0x79a66cc331e7 0x5bcdcc289c45 0x5bcdcc2a06a0 0x5bcdcc31dea6 0x5bcdcc2bd4ad 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2be648 0x5bcdcc344572 0x5bcdcc378ac8 0x5bcdcc2a7142 0x5bcdcc2be4f2 0x5bcdcc2a7142 0x5bcdcc2be4f2 0x5bcdcc2a7142 0x5bcdcc2b299c 0x5bcdcc2a2c5c 0x5bcdcc2be4f2 0x5bcdcc2a38fa 0x5bcdcc2c5177 0x5bcdcc2a2f3a 0x5bcdcc2c5177 0x5bcdcc2a2f3a 0x5bcdcc2aaf50 0x5bcdcc2bcba9 0x5bcdcc37f4c9 0x5bcdcc2aba6b 0x5bcdcc2a73e6
# Requirement already satisfied: tensorflow-io in /opt/conda/lib/python3.10/site-packages (0.31.0)
# Collecting tensorflow-io
#   Downloading tensorflow_io-0.32.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.0/28.0 MB 42.5 MB/s eta 0:00:0000:0100:01
# Collecting tensorflow-io-gcs-filesystem==0.32.0 (from tensorflow-io)
#   Downloading tensorflow_io_gcs_filesystem-0.32.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 72.7 MB/s eta 0:00:00
# Installing collected packages: tensorflow-io-gcs-filesystem, tensorflow-io
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.31.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.31.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.31.0
#   Attempting uninstall: tensorflow-io
#     Found existing installation: tensorflow-io 0.31.0
#     Uninstalling tensorflow-io-0.31.0:
#       Successfully uninstalled tensorflow-io-0.31.0
# Successfully installed tensorflow-io-0.32.0 tensorflow-io-gcs-filesystem-0.32.0
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 23524, done.
# remote: Counting objects: 100% (5956/5956), done.
# remote: Compressing objects: 100% (388/388), done.
# remote: Total 23524 (delta 5790), reused 5645 (delta 5568), pack-reused 17568
# Receiving objects: 100% (23524/23524), 30.69 MiB | 12.62 MiB/s, done.
# Resolving deltas: 100% (16572/16572), done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/models/Lora/jamz-2.1'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), 2.10 KiB | 717.00 KiB/s, done.
# Filtering content: 100% (10/10), 262.63 MiB | 70.05 MiB/s, done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/models/Lora/jamz-1.5'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), 2.10 KiB | 717.00 KiB/s, done.
# Filtering content: 100% (10/10), 181.12 MiB | 34.97 MiB/s, done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/embeddings/neutral'...
# remote: Enumerating objects: 61, done.
# remote: Total 61 (delta 0), reused 0 (delta 0), pack-reused 61
# Unpacking objects: 100% (61/61), 7.62 KiB | 557.00 KiB/s, done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/embeddings/negative'...
# remote: Enumerating objects: 18, done.
# remote: Total 18 (delta 0), reused 0 (delta 0), pack-reused 18
# Unpacking objects: 100% (18/18), 2.42 KiB | 827.00 KiB/s, done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/models/Lora/positive'...
# remote: Enumerating objects: 12, done.
# remote: Total 12 (delta 0), reused 0 (delta 0), pack-reused 12
# Unpacking objects: 100% (12/12), 1.56 KiB | 799.00 KiB/s, done.
# Filtering content: 100% (3/3), 239.93 MiB | 92.78 MiB/s, done.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 4620e8|OK  |   200MiB/s|/kaggle/temp/stable-diffusion-webui/models/ESRGAN/4x-UltraSharp.pth
#
# Status Legend:
# (OK):download completed.
# Exception caught
# Exception: [download_helper.cc:451] errorCode=1 Unrecognized URI or unsupported protocol: /kaggle/temp/stable-diffusion-webui/embeddings/negative
#
# --2023-07-17 08:24:47--  https://raw.githubusercontent.com/camenduru/stable-diffusion-webui-scripts/main/run_n_times.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 533 [text/plain]
# Saving to: ‘/kaggle/temp/stable-diffusion-webui/scripts/run_n_times.py’
#
# /kaggle/temp/stable 100%[===================>]     533  --.-KB/s    in 0s
#
# 2023-07-17 08:24:47 (15.3 MB/s) - ‘/kaggle/temp/stable-diffusion-webui/scripts/run_n_times.py’ saved [533/533]
#
# Cloning into '/kaggle/temp/stable-diffusion-webui/extensions/a1111-sd-webui-lycoris'...
# remote: Enumerating objects: 176, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 176 (delta 26), reused 33 (delta 18), pack-reused 122
# Receiving objects: 100% (176/176), 51.34 KiB | 4.67 MiB/s, done.
# Resolving deltas: 100% (99/99), done.99)
# Cloning into '/kaggle/temp/stable-diffusion-webui/extensions/tag-autocomplete'...
# remote: Enumerating objects: 1445, done.
# remote: Counting objects: 100% (1445/1445), done.
# remote: Compressing objects: 100% (546/546), done.
# remote: Total 1445 (delta 846), reused 1344 (delta 838), pack-reused 0
# Receiving objects: 100% (1445/1445), 3.90 MiB | 18.09 MiB/s, done.
# Resolving deltas: 100% (846/846), done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 172 (delta 32), reused 22 (delta 22), pack-reused 124
# Receiving objects: 100% (172/172), 65.50 KiB | 4.68 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/extensions/stable-diffusion-webui-huggingface'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 124 (delta 13), reused 10 (delta 10), pack-reused 106
# Receiving objects: 100% (124/124), 29.72 KiB | 7.43 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/extensions/sd-civitai-browser'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 163 (delta 37), reused 36 (delta 24), pack-reused 108
# Receiving objects: 100% (163/163), 38.97 KiB | 4.87 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-additional-networks'...
# remote: Enumerating objects: 809, done.
# remote: Counting objects: 100% (339/339), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 809 (delta 245), reused 226 (delta 208), pack-reused 470
# Receiving objects: 100% (809/809), 269.58 KiB | 6.42 MiB/s, done.
# Resolving deltas: 100% (454/454), done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet'...
# remote: Enumerating objects: 7427, done.
# remote: Counting objects: 100% (2192/2192), done.ts:  51% (1118/2192)
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 7427 (delta 2056), reused 2106 (delta 2042), pack-reused 5235
# Receiving objects: 100% (7427/7427), 15.40 MiB | 22.55 MiB/s, done.
# Resolving deltas: 100% (4297/4297), done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/extensions/openpose-editor'...
# remote: Enumerating objects: 403, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 403 (delta 88), reused 81 (delta 67), pack-reused 280
# Receiving objects: 100% (403/403), 1.15 MiB | 15.51 MiB/s, done.
# Resolving deltas: 100% (170/170), done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/extensions/stable-diffusion-webui-catppuccin'...
# remote: Enumerating objects: 202, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 202 (delta 73), reused 62 (delta 62), pack-reused 120
# Receiving objects: 100% (202/202), 13.43 MiB | 30.76 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/extensions/a1111-sd-webui-locon'...
# remote: Enumerating objects: 193, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 193 (delta 17), reused 41 (delta 16), pack-reused 150
# Receiving objects: 100% (193/193), 48.00 KiB | 3.43 MiB/s, done.
# Resolving deltas: 100% (95/95), done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/extensions/stable-diffusion-webui-rembg'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 27 (delta 7), reused 17 (delta 4), pack-reused 0
# Receiving objects: 100% (27/27), 1022.95 KiB | 18.27 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/extensions/stable-diffusion-webui-two-shot'...
# remote: Enumerating objects: 176, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 176 (delta 23), reused 21 (delta 21), pack-reused 136
# Receiving objects: 100% (176/176), 22.22 MiB | 28.08 MiB/s, done.
# Resolving deltas: 100% (80/80), done.
# Cloning into '/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-aspect-ratio-helper'...
# remote: Enumerating objects: 254, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 254 (delta 66), reused 65 (delta 55), pack-reused 153
# Receiving objects: 100% (254/254), 407.18 KiB | 11.00 MiB/s, done.
# Resolving deltas: 100% (121/121), done.
# /kaggle/temp/stable-diffusion-webui
# HEAD is now at baf6946e Merge branch 'release_candidate'
# fatal: cannot change to '/kaggle/temp/stable-diffusion-webui/repositories/stable-diffusion-stability-ai': No such file or directory
# [#ad62bf 688MiB/689MiB(99%) CN:1 DL:347MiB]]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ad62bf|OK  |   168MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11e_sd15_ip2p_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# [#aea4fe 388MiB/689MiB(56%) CN:16 DL:216MiB ETA:1s]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# aea4fe|OK  |   251MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11e_sd15_shuffle_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# [#94e7a0 569MiB/689MiB(82%) CN:16 DL:326MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 94e7a0|OK  |   323MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11p_sd15_canny_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# [#444977 582MiB/689MiB(84%) CN:16 DL:330MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 444977|OK  |   322MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11f1p_sd15_depth_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# [#9f860f 575MiB/689MiB(83%) CN:16 DL:322MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9f860f|OK  |   329MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11p_sd15_inpaint_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# [#a67667 595MiB/689MiB(86%) CN:16 DL:338MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a67667|OK  |   340MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11p_sd15_lineart_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# [#d90df8 574MiB/689MiB(83%) CN:16 DL:321MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d90df8|OK  |   323MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11p_sd15_mlsd_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# [#a452f3 577MiB/689MiB(83%) CN:16 DL:324MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a452f3|OK  |   330MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11p_sd15_normalbae_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# [#6bb624 611MiB/689MiB(88%) CN:16 DL:333MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 6bb624|OK  |   336MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11p_sd15_openpose_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# [#94006a 529MiB/689MiB(76%) CN:16 DL:291MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 94006a|OK  |   304MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11p_sd15_scribble_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# [#dbca09 551MiB/689MiB(80%) CN:16 DL:309MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# dbca09|OK  |   316MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11p_sd15_seg_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# [#0efd37 586MiB/689MiB(85%) CN:16 DL:329MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 0efd37|OK  |   330MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11p_sd15_softedge_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# [#03d4f4 595MiB/689MiB(86%) CN:16 DL:328MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 03d4f4|OK  |   334MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11p_sd15s2_lineart_anime_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
# [#20ba97 520MiB/689MiB(75%) CN:16 DL:299MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 20ba97|OK  |   293MiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11f1e_sd15_tile_fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 13fd66|OK  |   173KiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11e_sd15_ip2p_fp16.yaml
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3c864b|OK  |   161KiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11e_sd15_shuffle_fp16.yaml
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 2e4edd|OK  |   146KiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11p_sd15_canny_fp16.yaml
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c4665f|OK  |   173KiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11f1p_sd15_depth_fp16.yaml
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 79250e|OK  |   158KiB/s|/kaggle/temp/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11p_sd15_inpaint_fp16.yaml
#
# Status Legend:
# (OK):download completed.
#
